# %%
from concurrent.futures import ThreadPoolExecutor
from typing import Optional

import pandas as pd
import requests
from tqdm.auto import tqdm

# %%
tickers = requests.get(
    "https://fiin-core.ssi.com.vn/Master/GetListOrganization?language=vi"
).json()["items"]
tickers_df = pd.DataFrame(tickers)
tickers_df['comGroupCode'].unique()
# Out:
# array(['UpcomIndex', 'HNXIndex', 'VNINDEX'], dtype=object)

# %%
ticker_must_create = set(tickers_df["ticker"].tolist())

# %%
tickers_df_must_create = tickers_df[tickers_df["ticker"].isin(ticker_must_create)]
tickers_df_must_create
# Out:
#        organCode ticker comGroupCode icbCode organTypeCode comTypeCode  \
# 0     0104498100    VVS   UpcomIndex    3353            DN          CT
# 1     0304941312    XDC   UpcomIndex    2357            DN          CT
# 2          10659    HSV   UpcomIndex    1757         OTHER          CT
# 3          10669    CST   UpcomIndex    1771         OTHER          CT
# 4          10708    BVL   UpcomIndex    8637         OTHER          CT
# ...          ...    ...          ...     ...           ...         ...
# 1626  XUANMINHHP    XMP   UpcomIndex    7535         OTHER          CT
# 1627         YBC    YBC   UpcomIndex    2353         OTHER          CT
# 1628        YBMC    YBM      VNINDEX    1775         OTHER          CT
# 1629     YEGCORP    YEG      VNINDEX    5553         OTHER          CT
# 1630       YTECO    YTC   UpcomIndex    4537         OTHER          CT
#
#                                               organName  \
# 0        Công ty Cổ phần Đầu tư Phát triển Máy Việt Nam
# 1         Công ty TNHH MTV Xây dựng Công trình Tân Cảng
# 2                      Công ty Cổ phần Gang Thép Hà Nội
# 3                    Công ty Cổ phần Than Cao Sơn - TKV
# 4                               Công ty Cổ phần BV Land
# ...                                                 ...
# 1626                Công ty Cổ phần Thủy điện Xuân Minh
# 1627      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 1628     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 1629                     Công ty Cổ phần Tập đoàn Yeah1
# 1630  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
#
#                       organShortName
# 0     Đầu tư Phát triển Máy Việt Nam
# 1       Xây dựng Công trình Tân Cảng
# 2                   Gang Thép Hà Nội
# 3                 Than Cao Sơn - TKV
# 4                            BV Land
# ...                              ...
# 1626             Thủy điện Xuân Minh
# 1627   Xi măng và Khoáng sản Yên Bái
# 1628           Khoáng sản CN Yên Bái
# 1629                  Tập đoàn Yeah1
# 1630                 XNK Y tế TP.HCM
#
# [1631 rows x 8 columns]

# %%
def get_ticker_info(ticker: str) -> Optional[dict]:
    print(ticker)
    try:
        ticker_info = requests.get(
            f"https://apipubaws.tcbs.com.vn/tcanalysis/v1/ticker/{ticker}/overview"
        ).json()
    except Exception as e:
        logger.error(
            "Error when getting ticker: {ticker} info from tcbs: {error}",
            ticker=ticker,
            error=str(e),
        )
        return None
    return ticker_info

# %%
with ThreadPoolExecutor(max_workers=20) as executor:
    tickers_info = list(
        tqdm(executor.map(get_ticker_info, ticker_must_create), total=len(ticker_must_create))
    )
# Out:
# ICI
# TNA
# VMS
# IPA
# TTC
# AAV
# PTH
# NAP
# MPC
# BSP
# HPD
# VNL
# VFG
# NCT
# LHC
# KHA
# GER
# FBC
# TNW
# CMT
#   0%|          | 0/1631 [00:00<?, ?it/s]
# TSG
# TW3
# NDN
# CSM
# TNG
# CTC
# NBT
# SSN
# ELC
# SIC
# SBR
# PCG
# CNN
# MCF
# ILB
# ST8
# VNG
# BDT
# TCO
# TOW
# SQC
# WSS
# TR1
# DRH
# CII
# SSF
# MH3
# BQB
# TTH
# SSH
# VOS
# CLC
# XMD
# HNM
# TLP
# ALV
# HTV
# DFF
# HAT
# VIP
# LM7
# ONW
# HNA
# SDY
# GLW
# SGB
# BTB
# QHD
# FUEKIVFS
# PCM
# PVD
# TTE
# SCY
# ATB
# HID
# SHA
# PTP
# MCD
# RDP
# THG
# HEC
# THP
# BKH
# NLG
# DP1
# EPH
# CBI
# IN4
# FCM
# FUEDCMID
# VCC
# IRC
# DS3
# SIP
# SHG
# CID
# VNT
# HAN
# DRI
# IME
# ILS
# SBA
# MEF
# BIG
# VOC
# KHG
# QNC
# SDK
# TVN
# PAI
# CSV
# MSH
# TCM
# PIS
# PNG
# HUB
# V21
# HGM
# HDPTMX
#
# CAN
# TVB
# BRS
# CAR
# PTG
# GSP
# BMD
# SEB
# MGG
# TYA
# HVT
# HAS
# GEX
# UPH
# ATA
# IBD
# SCD
# HPP
# PCC
# POV
# CFM
# VTG
# DNP
# PET
# PVP
# TOT
# DMC
# VSI
# SFG
# NXT
# PVM
# BHG
# SC5
# SMN
# KPF
# MCO
# DTH
# HAI
# BRC
# NQB
# DID
# BIC
# BMC
# ACL
# SMA
# VGV
# MVB
# L43
# LBC
# HLS
# PSP
# LWS
# MQB
# FUCTVGF4
# VTS
# PTC
# VRE
# X26
# VND
# GPC
# MTV
# TMS
# CTI
# DHC
# THN
# TDC
# PEG
# SFI
# PTD
# PAC
# KHD
# PVG
# MCP
# TTS
# TQW
# TDG
# A32
# PVE
# VC6
# S27
# CTB
# APG
# TV2
# CTA
# APF
# NTT
# TJC
# MPT
# HAF
# VE1
# CDP
# ICT
# HTL
# GCF
# CMK
# BVS
# PNJ
# BT1
# BNW
# FRT
# LMH
# NED
# TCK
# NAU
# TAW
# HRB
# NDX
# DNL
# PMW
# MLS
# RIC
# VTV
# CTS
# DLR
# ABT
# CDO
# S4A
# BLF
# HD6
# VLF
# MIC
# PIA
# DTN
# NBE
# NSH
# MAS
# VSF
# TLG
# E1VFVN30
# TN1
# USC
# PGT
# NET
# NBC
# HBD
# PJS
# HVH
# SDB
# IFS
# PRT
# PAP
# VIX
# BRR
# GVR
# H11
# CPH
# LSG
# STT
# BTT
# IMP
# VNE
# SAS
# DAS
# PEQ
# PGS
# BDG
# SCS
# CDN
# CLH
# NVT
# TCL
# ISH
# SZL
# PBT
# FCN
# DCH
# HND
# HDG
# PGN
# C12
# TDN
# TC6
# SGT
# S12
# VCI
# HDW
# HDC
# CBS
# VNH
# SHC
# TAR
# BMJ
# PPY
# BBH
# MES
# DHG
# QNU
# TSC
# DLM
# TTP
# TCR
# FLC
# KHL
# SSC
# PMT
# KMR
# ABC
# VCE
# KBC
# BVH
# DAD
# TPB
# UIC
# BTS
# VIN
# VDN
# TMW
# PXS
# KIP
# GMA
# IVS
# NSG
# BTU
# HHR
# CTD
# IBC
# SFN
# PVR
# SVD
# SEP
# VAV
# CMV
# SPH
# L40
# BAX
# TVG
# PXL
# DVC
# VPS
# CAD
# CHP
# ALT
# GMX
# PNC
# BAB
# TCT
# VRG
# SJE
# MTL
# KAC
# BHK
# PLE
# HAV
# UDJ
# EIB
# BSD
# SZB
# VTP
# KMT
# PMJ
# ACV
# ASA
# MCG
# VGLCNA
#
# BVN
# XMP
# MBB
# C36
# PTL
# GLC
# TKU
# VAB
# NBP
# VNS
# ILC
# CDR
# DXG
# NDC
# HTN
# HNB
# PVC
# FUEKIV30
# LCM
# VGI
# HCT
# ADS
# BNA
# PMP
# HKP
# SGR
# TTL
# DUS
# HSI
# VXP
# ACE
# DTA
# HEM
# VLB
# XMC
# VWS
# MDF
# HPX
# HDA
# KSK
# ITS
# DTT
# GTA
# SEA
# TLT
# VTC
# VCM
# MAC
# USD
# DXPBCA
#
# IDI
# VJC
# BST
# FIR
# V11
# SCG
# PCH
# HBS
# TQN
# ACC
# TTA
# MVC
# QHW
# ITC
# VNB
# DSP
# FOX
# VLC
# VE9
# DAP
# CRC
# NTC
# PHR
# HCC
# HHS
# BAL
# BTH
# PMG
# RTB
# FGL
# PGD
# KLB
# KHW
# NHC
# GTT
# MTH
# PGC
# DCG
# NST

# %%
tickers_info = list(filter(lambda ticker_info: ticker_info is not None, tickers_info))
tickers_info = pd.DataFrame(tickers_info)

# %%
industies = tickers_info[["industryID", "industry", "industryEn"]]
industies
# Out:
#       industryID                       industry                   industryEn
# 0          181.0           Xây dựng và Vật liệu     Construction & Materials
# 1          159.0              Tài nguyên Cơ bản              Basic Resources
# 2          193.0     Hàng & Dịch vụ Công nghiệp  Industrial Goods & Services
# 3          195.0     Hàng & Dịch vụ Công nghiệp  Industrial Goods & Services
# 4          180.0           Xây dựng và Vật liệu     Construction & Materials
# ...          ...                            ...                          ...
# 1626       260.0            Du lịch và Giải trí             Travel & Leisure
# 1627       199.0     Hàng & Dịch vụ Công nghiệp  Industrial Goods & Services
# 1628       275.0  Điện, nước & xăng dầu khí đốt                    Utilities
# 1629       226.0        Hàng cá nhân & Gia dụng   Personal & Household Goods
# 1630       229.0        Hàng cá nhân & Gia dụng   Personal & Household Goods
#
# [1631 rows x 3 columns]
