# %%
categories = [
    {
        "CategoryName": "Danh mục quan tâm",
        "ListStockCode": ["NLG", "DXG", "SZC", "FTS", "HUT", "VIB", "VCI", "STB"],
    },
    {
        "CategoryName": "BDS",
        "ListStockCode": [
            "DXS",
            "DXG",
            "NLG",
            "KDH",
            "HDC",
            "ASM",
            "HDG",
            "PDR",
            "DIG",
            "VHM",
            "VIC",
            "NVL",
        ],
    },
    {
        "CategoryName": "BDS - KCN",
        "ListStockCode": ["BCM", "VGC", "SZC", "GVR", "KBC", "PHR", "IDC"],
    },
    {
        "CategoryName": "Bán lẻ",
        "ListStockCode": ["HAX", "PNJ", "PET", "VRE", "VTP", "VNM", "MSN", "FRT", "MWG", "DGW"],
    },
    {
        "CategoryName": "Bảo Hiểm",
        "ListStockCode": ["MIG", "BVH", "BMI"],
    },
    {
        "CategoryName": "Cao su",
        "ListStockCode": ["DRI", "DRC", "DPR", "PHR", "GVR"],
    },
    {
        "CategoryName": "Chứng Khoán",
        "ListStockCode": ["FTS", "VND", "VCI", "MBS", "HCM", "SHS", "SSI"],
    },
    {
        "CategoryName": "Cảng Biển, Vận Tải",
        "ListStockCode": ["SGP", "HAH", "GMD"],
    },
    {
        "CategoryName": "Dầu khí",
        "ListStockCode": ["OIL", "PLX", "GAS", "BSR", "PVT", "PVS", "CNG", "PVD"],
    },
    {
        "CategoryName": "Dệt may",
        "ListStockCode": ["GIL", "MSH", "TNG", "VGT"],
    },
    {
        "CategoryName": "Ngân Hàng",
        "ListStockCode": [
            "LPB",
            "VIB",
            "OCB",
            "HDB",
            "BID",
            "VCB",
            "MSB",
            "ACB",
            "CTG",
            "MBB",
            "SHB",
            "STB",
            "TCB",
            "TPB",
            "VPB",
        ],
    },
    {
        "CategoryName": "Phân Bón, Hóa chất",
        "ListStockCode": ["DGC", "DPM", "DCM"],
    },
    {
        "CategoryName": "Thép",
        "ListStockCode": ["NKG", "HSG", "HPG"],
    },
    {
        "CategoryName": "Thủy sản",
        "ListStockCode": ["CMX", "ANV", "ASM", "FMC", "VHC"],
    },
    {
        "CategoryName": "Xây dựng",
        "ListStockCode": ["VCG", "HTN", "CTD", "LCG", "C4G", "CII", "CTR", "HBC"],
    },
    {
        "CategoryName": "Điện gió",
        "ListStockCode": ["NT2", "POW", "PC1", "GEG", "REE", "HDG", "BCG"],
    },
    {
        "CategoryName": "Đường, thực phẩm, gạo",
        "ListStockCode": ["HAG", "TAR", "LTG", "DBC", "KDC", "PAN", "SBT"],
    },
    {
        "CategoryName": "Đầu tư công",
        "ListStockCode": [
            "FCN",
            "C4G",
            "DHA",
            "PLC",
            "VCG",
            "HHV",
            "KSB",
            "LCG",
            "BCC",
            "HT1",
            "PC1",
        ],
    },
]

# %%
import requests

headers = {
    'authority': 'stockk.dscilab.site:20007',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'vi,en;q=0.9',
    'authorization': 'Basic Og==',
    'content-type': 'application/x-www-form-urlencoded',
    'origin': 'https://stockk.dscilab.site:20007',
    'referer': 'https://stockk.dscilab.site:20007/swagger/index.html',
    'sec-ch-ua': '"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

data = {
    'grant_type': 'password',
    'username': 'root@gmail.com',
    'password': 'root_password',
}

response = requests.post('https://stockk.dscilab.site:20007/api/auth/login', headers=headers, data=data)
access_token = response.json()['access_token']
access_token
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdG9ja2stZ28iLCJzdWIiOiIxIiwiZXhwIjoxNjgxNzQ2MjIwLCJuYmYiOjE2ODE3NDUzMjAsImlhdCI6MTY4MTc0NTMyMCwiZW1haWwiOiJyb290QGdtYWlsLmNvbSIsImlkIjoxfQ.ibOYOrzXZi-3y5PrisDYnqPNGftaaxdwDxpuSZEv6TYw6G7nQCET1B5CGmlcXkvft2EgR877X0JCu88vqMR6yBBTAPTVXsyCmJLRjQwxs71Xc0GLwGEKvJ5l0vw5OiZ_9vxdqhK7RUYojlw8GbTFbgoSLlirsSJ-SRxLEO0Ta7s'

# %%
import requests

headers = {
    "authority": "stockk.dscilab.site:20007",
    "accept": "*/*",
    "accept-language": "vi,en;q=0.9",
    "authorization": f"Bearer {access_token}",
    "content-type": "application/json",
    "origin": "http://localhost:3000",
    "referer": "http://localhost:3000/",
    "sec-ch-ua": '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Linux"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "cross-site",
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36",
}

for category in categories:
    name = category["CategoryName"]
    tickers = category["ListStockCode"]

    json_data = {
        "name": name,
        "tickers": tickers,
    }

    response = requests.post(
        "https://stockk.dscilab.site:20007/api/watchlist", headers=headers, json=json_data
    )
    
    print(response.json())
# Out:
# {'data': {'id': 1, 'created_at': '2023-04-17T15:28:40.81488Z', 'updated_at': '2023-04-17T15:28:40.81488Z', 'name': 'Danh mục quan tâm', 'tickers': ['NLG', 'DXG', 'SZC', 'FTS', 'HUT', 'VIB', 'VCI', 'STB'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 2, 'created_at': '2023-04-17T15:28:41.213426Z', 'updated_at': '2023-04-17T15:28:41.213426Z', 'name': 'BDS', 'tickers': ['DXS', 'DXG', 'NLG', 'KDH', 'HDC', 'ASM', 'HDG', 'PDR', 'DIG', 'VHM', 'VIC', 'NVL'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 3, 'created_at': '2023-04-17T15:28:41.307587Z', 'updated_at': '2023-04-17T15:28:41.307587Z', 'name': 'BDS - KCN', 'tickers': ['BCM', 'VGC', 'SZC', 'GVR', 'KBC', 'PHR', 'IDC'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 4, 'created_at': '2023-04-17T15:28:41.499327Z', 'updated_at': '2023-04-17T15:28:41.499327Z', 'name': 'Bán lẻ', 'tickers': ['HAX', 'PNJ', 'PET', 'VRE', 'VTP', 'VNM', 'MSN', 'FRT', 'MWG', 'DGW'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 5, 'created_at': '2023-04-17T15:28:41.591649Z', 'updated_at': '2023-04-17T15:28:41.591649Z', 'name': 'Bảo Hiểm', 'tickers': ['MIG', 'BVH', 'BMI'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 6, 'created_at': '2023-04-17T15:28:41.688338Z', 'updated_at': '2023-04-17T15:28:41.688338Z', 'name': 'Cao su', 'tickers': ['DRI', 'DRC', 'DPR', 'PHR', 'GVR'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 7, 'created_at': '2023-04-17T15:28:41.874002Z', 'updated_at': '2023-04-17T15:28:41.874002Z', 'name': 'Chứng Khoán', 'tickers': ['FTS', 'VND', 'VCI', 'MBS', 'HCM', 'SHS', 'SSI'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 8, 'created_at': '2023-04-17T15:28:41.976602Z', 'updated_at': '2023-04-17T15:28:41.976602Z', 'name': 'Cảng Biển, Vận Tải', 'tickers': ['SGP', 'HAH', 'GMD'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 9, 'created_at': '2023-04-17T15:28:42.066562Z', 'updated_at': '2023-04-17T15:28:42.066562Z', 'name': 'Dầu khí', 'tickers': ['OIL', 'PLX', 'GAS', 'BSR', 'PVT', 'PVS', 'CNG', 'PVD'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 10, 'created_at': '2023-04-17T15:28:42.164592Z', 'updated_at': '2023-04-17T15:28:42.164592Z', 'name': 'Dệt may', 'tickers': ['GIL', 'MSH', 'TNG', 'VGT'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 11, 'created_at': '2023-04-17T15:28:42.255429Z', 'updated_at': '2023-04-17T15:28:42.255429Z', 'name': 'Ngân Hàng', 'tickers': ['LPB', 'VIB', 'OCB', 'HDB', 'BID', 'VCB', 'MSB', 'ACB', 'CTG', 'MBB', 'SHB', 'STB', 'TCB', 'TPB', 'VPB'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 12, 'created_at': '2023-04-17T15:28:42.446167Z', 'updated_at': '2023-04-17T15:28:42.446167Z', 'name': 'Phân Bón, Hóa chất', 'tickers': ['DGC', 'DPM', 'DCM'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 13, 'created_at': '2023-04-17T15:28:42.542974Z', 'updated_at': '2023-04-17T15:28:42.542974Z', 'name': 'Thép', 'tickers': ['NKG', 'HSG', 'HPG'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 14, 'created_at': '2023-04-17T15:28:42.637806Z', 'updated_at': '2023-04-17T15:28:42.637806Z', 'name': 'Thủy sản', 'tickers': ['CMX', 'ANV', 'ASM', 'FMC', 'VHC'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 15, 'created_at': '2023-04-17T15:28:42.886248Z', 'updated_at': '2023-04-17T15:28:42.886248Z', 'name': 'Xây dựng', 'tickers': ['VCG', 'HTN', 'CTD', 'LCG', 'C4G', 'CII', 'CTR', 'HBC'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 16, 'created_at': '2023-04-17T15:28:43.104483Z', 'updated_at': '2023-04-17T15:28:43.104483Z', 'name': 'Điện gió', 'tickers': ['NT2', 'POW', 'PC1', 'GEG', 'REE', 'HDG', 'BCG'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 17, 'created_at': '2023-04-17T15:28:43.206103Z', 'updated_at': '2023-04-17T15:28:43.206103Z', 'name': 'Đường, thực phẩm, gạo', 'tickers': ['HAG', 'TAR', 'LTG', 'DBC', 'KDC', 'PAN', 'SBT'], 'owner_id': 1}, 'error': None, 'is_success': True}
# {'data': {'id': 18, 'created_at': '2023-04-17T15:28:43.296479Z', 'updated_at': '2023-04-17T15:28:43.296479Z', 'name': 'Đầu tư công', 'tickers': ['FCN', 'C4G', 'DHA', 'PLC', 'VCG', 'HHV', 'KSB', 'LCG', 'BCC', 'HT1', 'PC1'], 'owner_id': 1}, 'error': None, 'is_success': True}
