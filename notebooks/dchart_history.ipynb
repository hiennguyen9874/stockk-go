# %%
import pandas as pd
import numpy as np

# %%
import time
import datetime
from datetime import timezone


# Getting the current date
# and time
dt = datetime.datetime.now(timezone.utc)

utc_time = dt.replace(tzinfo=timezone.utc)
utc_timestamp = utc_time.timestamp()

print(utc_timestamp, time.time())
# Out:
# 1680409707.971528 1680409707.9716065

# %%
import math

symbol = "TCB"
resolution = "1"
from_time = 1431907200
to_time = int(math.floor(utc_timestamp))
from_time, to_time
# Out:
# (1431907200, 1680409707)

# %% [markdown]
# ## TCBS

# %%
# %%time
import requests

headers = {
    "sec-ch-ua": '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
    "Accept-language": "vi",
    "sec-ch-ua-mobile": "?0",
    # "Authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....tBOHbPGUdpuFWG_7BxtwJqMa6jVGwVi1ykD-IPFQ2pBiZUtgNvXLuqxLkvPpK_vjRvVSbZCi0lIootrrkNtCoitxhwQmSV1i7CjhCTR8tbPCZIAVO91-e24yln6LVTq_5500Av6xbhx1WB2llxfQFaOYM31AiFmt_2aBL7hxToxmoJNEV349PqlehXo5GS6VYKb-OcCgTsgDe5UXbaso6kI78AsqMCF7-rUo8Eu-y61vv7ibzIkBs1_YEVbhxsIbplpJDTseIKBRwM5YFHLYH7jSReXl0_A4pZez2iSaeo3pfSx1FvtVAlrx9sX2jMbyrjYRjCzZP1LzJJkrltlc1A",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
    "Content-Type": "application/json",
    "Accept": "application/json",
    "Referer": "https://tcinvest.tcbs.com.vn/",
    "sec-ch-ua-platform": '"Linux"',
}

params = {
    "ticker": symbol,
    "type": "stock",
    "resolution": resolution,
    # "from": from_time,
    "to": to_time,
    "countBack": "1000",
}

response = requests.get(
    "https://apipubaws.tcbs.com.vn/stock-insight/v2/stock/bars", params=params, headers=headers
)

results = response.json()

df = pd.DataFrame(results["data"])
df["tradingDate"] = (
    (pd.to_datetime(df["tradingDate"]).astype(int) / 10**9).apply(np.floor).astype(int)
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   open         250 non-null    float64
#  1   high         250 non-null    float64
#  2   low          250 non-null    float64
#  3   close        250 non-null    float64
#  4   volume       250 non-null    int64
#  5   tradingDate  250 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 11.8 KB
# CPU times: user 149 ms, sys: 1.5 ms, total: 151 ms
# Wall time: 511 ms

# %%
# import pandas as pd
# import requests

# headers = {
#     "sec-ch-ua": '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
#     "Accept-language": "vi",
#     "sec-ch-ua-mobile": "?0",
#     # 'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....tBOHbPGUdpuFWG_7BxtwJqMa6jVGwVi1ykD-IPFQ2pBiZUtgNvXLuqxLkvPpK_vjRvVSbZCi0lIootrrkNtCoitxhwQmSV1i7CjhCTR8tbPCZIAVO91-e24yln6LVTq_5500Av6xbhx1WB2llxfQFaOYM31AiFmt_2aBL7hxToxmoJNEV349PqlehXo5GS6VYKb-OcCgTsgDe5UXbaso6kI78AsqMCF7-rUo8Eu-y61vv7ibzIkBs1_YEVbhxsIbplpJDTseIKBRwM5YFHLYH7jSReXl0_A4pZez2iSaeo3pfSx1FvtVAlrx9sX2jMbyrjYRjCzZP1LzJJkrltlc1A',
#     "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
#     "Content-Type": "application/json",
#     "Accept": "application/json",
#     "Referer": "https://tcinvest.tcbs.com.vn/",
#     "sec-ch-ua-platform": '"Linux"',
# }

# params = {
#     "ticker": "TCB",
#     "type": "stock",
#     "resolution": "W",
#     "to": "1673913600",
#     "countBack": "301",
# }

# response = requests.get(
#     "https://apipubaws.tcbs.com.vn/stock-insight/v2/stock/bars-long-term",
#     params=params,
#     headers=headers,
# )

# results = response.json()
# df = pd.DataFrame(results["data"])
# df["tradingDate"] = pd.to_datetime(df["tradingDate"])
# df

# %% [markdown]
# ## SSI

# %%
# %%time
import requests

headers = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Language": "vi,en;q=0.9",
    "Connection": "keep-alive",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
    "sec-ch-ua": '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Linux"',
}

params = {
    "resolution": resolution,
    "symbol": symbol,
    "from": str(from_time),
    "to": str(to_time),
}

response = requests.get(
    "https://iboard.ssi.com.vn/dchart/api/history",
    params=params,
    # cookies=cookies,
    headers=headers,
)
results = response.json()

print(results)

df = pd.DataFrame(
    {
        "open": results["o"],
        "high": results["h"],
        "low": results["l"],
        "close": results["c"],
        "volume": results["v"],
        "tradingDate": results["t"],
    }
)
df["tradingDate"] = pd.to_datetime(df["tradingDate"], unit="s")
df
# Out:
# {'t': [1676513748, 1676513803, 1676513855, 1676513896, 1676513997, 1676514050, 1676514100, 1676514176, 1676514222, 1676514279, 1676514305, 1676514407, 1676514476, 1676514534, 1676514596, 1676514639, 1676514765, 1676514829, 1676514850, 1676514957, 1676515013, 1676515061, 1676515103, 1676515184, 1676515203, 1676515315, 1676515377, 1676515390, 1676515487, 1676515614, 1676515665, 1676515692, 1676515798, 1676515829, 1676515907, 1676516012, 1676516153, 1676516195, 1676516276, 1676516299, 1676516373, 1676516456, 1676516519, 1676516573, 1676516629, 1676516673, 1676516707, 1676516815, 1676516878, 1676516931, 1676516994, 1676517036, 1676517064, 1676517179, 1676517261, 1676517352, 1676517415, 1676517462, 1676517527, 1676517580, 1676517640, 1676517697, 1676517752, 1676517838, 1676517894, 1676517958, 1676517987, 1676518078, 1676518122, 1676518183, 1676518255, 1676518286, 1676518324, 1676518401, 1676518475, 1676518515, 1676518617, 1676518640, 1676518728, 1676518741, 1676519018, 1676519137, 1676519
# ...

# %% [markdown]
# ## VPS

# %%
# %%time
import requests
import pandas as pd

headers = {
    "Accept": "*/*",
    "Accept-Language": "vi,en;q=0.9",
    "Connection": "keep-alive",
    "Origin": "https://chart.vps.com.vn",
    "Referer": "https://chart.vps.com.vn/",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
    "sec-ch-ua": '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Linux"',
}

params = {
    "resolution": resolution,
    "symbol": symbol,
    "from": str(from_time),
    "to": str(to_time),
}

response = requests.get(
    "https://histdatafeed.vps.com.vn/tradingview/history", params=params, headers=headers
)

results = response.json()

df = pd.DataFrame(
    {
        "open": results["o"],
        "high": results["h"],
        "low": results["l"],
        "close": results["c"],
        "volume": results["v"],
        "tradingDate": results["t"],
    }
)
df["tradingDate"] = pd.to_datetime(df["tradingDate"], unit='s')
df
# Out:
# CPU times: user 83.6 ms, sys: 0 ns, total: 83.6 ms
# Wall time: 209 ms
#        open   high    low  close  volume         tradingDate
# 0     27.80  27.80  27.70  27.80   36300 2023-01-09 02:15:00
# 1     27.80  27.80  27.80  27.80    1300 2023-01-09 02:16:00
# 2     27.80  27.80  27.80  27.80   11400 2023-01-09 02:17:00
# 3     27.85  27.85  27.85  27.85    2800 2023-01-09 02:18:00
# 4     27.85  27.85  27.70  27.70   62800 2023-01-09 02:19:00
# ...     ...    ...    ...    ...     ...                 ...
# 1048  27.80  27.85  27.80  27.85   11800 2023-01-13 07:27:00
# 1049  27.85  27.85  27.80  27.85   22100 2023-01-13 07:28:00
# 1050  27.85  27.85  27.80  27.80   51400 2023-01-13 07:29:00
# 1051  27.80  27.80  27.80  27.80     700 2023-01-13 07:30:00
# 1052  27.80  27.80  27.80  27.80  157800 2023-01-13 07:45:00
#
# [1053 rows x 6 columns]

# %% [markdown]
# ## VND

# %%
# %%time
import requests
import pandas as pd

headers = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Language": "vi,en;q=0.9",
    "Connection": "keep-alive",
    "Origin": "https://dchart.vndirect.com.vn",
    "Referer": "https://dchart.vndirect.com.vn/",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
    "sec-ch-ua": '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Linux"',
}

params = {
    "resolution": resolution,
    "symbol": symbol,
    "from": str(from_time),
    "to": str(to_time),
}

response = requests.get(
    "https://dchart-api.vndirect.com.vn/dchart/history", params=params, headers=headers
)

results = response.json()

df = pd.DataFrame(
    {
        "open": results["o"],
        "high": results["h"],
        "low": results["l"],
        "close": results["c"],
        "volume": results["v"],
        "tradingDate": results["t"],
    }
)
df["tradingDate"] = pd.to_datetime(df["tradingDate"], unit='s')
df
# Out:
# CPU times: user 126 ms, sys: 2.74 ms, total: 129 ms
# Wall time: 3 s
#         open   high   low  close  volume         tradingDate
# 0      53.50  53.50  53.4  53.40  179000 2021-11-05 02:15:00
# 1      53.50  53.50  53.3  53.30   42900 2021-11-05 02:16:00
# 2      53.30  53.40  53.2  53.30   86200 2021-11-05 02:17:00
# 3      53.30  53.40  53.3  53.30   18900 2021-11-05 02:18:00
# 4      53.30  53.30  53.2  53.30    7000 2021-11-05 02:19:00
# ...      ...    ...   ...    ...     ...                 ...
# 28931  27.80  27.85  27.8  27.85   11800 2023-01-13 07:27:00
# 28932  27.85  27.85  27.8  27.85   22100 2023-01-13 07:28:00
# 28933  27.85  27.85  27.8  27.80   51400 2023-01-13 07:29:00
# 28934  27.80  27.80  27.8  27.80     700 2023-01-13 07:30:00
# 28935  27.80  27.80  27.8  27.80  157800 2023-01-13 07:45:00
#
# [28936 rows x 6 columns]

# %% [markdown]
# ## MBS

# %%
# %%time
import requests
import pandas as pd

headers = {
    "authority": "plus24.mbs.com.vn",
    "accept": "*/*",
    "accept-language": "vi,en;q=0.9",
    "referer": "https://plus24.mbs.com.vn/apps/StockBoard/MBS/chi-tiet-ma.html?id=ACB",
    "sec-ch-ua": '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Linux"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
}

params = {
    "resolution": resolution,
    "symbol": symbol,
    "from": str(from_time),
    "to": str(to_time),
}

response = requests.get(
    "https://plus24.mbs.com.vn/tradingview/api/1.1/history",
    params=params,
    headers=headers,
)

results = response.json()

df = pd.DataFrame(
    {
        "open": results["o"],
        "high": results["h"],
        "low": results["l"],
        "close": results["c"],
        "volume": results["v"],
        "tradingDate": results["t"],
    }
)
df["tradingDate"] = pd.to_datetime(df["tradingDate"], unit='s')
df
# Out:
# CPU times: user 235 ms, sys: 6.91 ms, total: 242 ms
# Wall time: 3.41 s
#         open   high    low  close    volume         tradingDate
# 0      51.70  51.80  51.70  51.80  189400.0 2021-11-01 02:15:00
# 1      51.70  51.90  51.70  51.80   70500.0 2021-11-01 02:16:00
# 2      51.80  51.80  51.70  51.80   41800.0 2021-11-01 02:17:00
# 3      51.80  51.80  51.70  51.80   58700.0 2021-11-01 02:18:00
# 4      51.80  51.80  51.60  51.70  109000.0 2021-11-01 02:19:00
# ...      ...    ...    ...    ...       ...                 ...
# 67434  27.85  27.90  27.80  27.80   14100.0 2023-01-13 07:26:00
# 67435  27.85  27.85  27.85  27.85   22600.0 2023-01-13 07:27:00
# 67436  27.85  27.85  27.80  27.85   33200.0 2023-01-13 07:28:00
# 67437  27.85  27.85  27.80  27.80   30100.0 2023-01-13 07:29:00
# 67438  27.80  27.80  27.80  27.80  157800.0 2023-01-13 07:45:00
#
# [67439 rows x 6 columns]
