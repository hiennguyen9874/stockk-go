# %%
def msgArrayToDict(msg_type, arr):
    if msg_type == "S":
        if arr[0] == "SFU":
            if arr[2] == "ST":
                return dict(
                    zip(
                        (
                            "code",
                            "stockType",
                            "floorCode",
                            "basicPrice",
                            "floorPrice",
                            "ceilingPrice",
                            "bidPrice01",
                            "bidPrice02",
                            "bidPrice03",
                            "bidPrice04",
                            "bidPrice05",
                            "bidPrice06",
                            "bidPrice07",
                            "bidPrice08",
                            "bidPrice09",
                            "bidPrice10",
                            "bidQtty01",
                            "bidQtty02",
                            "bidQtty03",
                            "bidQtty04",
                            "bidQtty05",
                            "bidQtty06",
                            "bidQtty07",
                            "bidQtty08",
                            "bidQtty09",
                            "bidQtty10",
                            "offerPrice01",
                            "offerPrice02",
                            "offerPrice03",
                            "offerPrice04",
                            "offerPrice05",
                            "offerPrice06",
                            "offerPrice07",
                            "offerPrice08",
                            "offerPrice09",
                            "offerPrice10",
                            "offerQtty01",
                            "offerQtty02",
                            "offerQtty03",
                            "offerQtty04",
                            "offerQtty05",
                            "offerQtty06",
                            "offerQtty07",
                            "offerQtty08",
                            "offerQtty09",
                            "offerQtty10",
                            "totalBidQtty",
                            "totalOfferQtty",
                            "tradingSessionId",
                            "buyForeignQtty",
                            "sellForeignQtty",
                            "highestPrice",
                            "lowestPrice",
                            "accumulatedVal",
                            "accumulatedVol",
                            "matchPrice",
                            "matchQtty",
                            "currentPrice",
                            "currentQtty",
                            "projectOpen",
                            "totalRoom",
                            "currentRoom",
                        ),
                        arr[1:],
                    )
                )
            elif arr[2] == "W":
                return dict(
                    zip(
                        (
                            "code",
                            "stockType",
                            "floorCode",
                            "basicPrice",
                            "floorPrice",
                            "ceilingPrice",
                            "underlyingSymbol",
                            "issuerName",
                            "exercisePrice",
                            "exerciseRatio",
                            "bidPrice01",
                            "bidPrice02",
                            "bidPrice03",
                            "bidQtty01",
                            "bidQtty02",
                            "bidQtty03",
                            "offerPrice01",
                            "offerPrice02",
                            "offerPrice03",
                            "offerQtty01",
                            "offerQtty02",
                            "offerQtty03",
                            "totalBidQtty",
                            "totalOfferQtty",
                            "tradingSessionId",
                            "buyForeignQtty",
                            "sellForeignQtty",
                            "highestPrice",
                            "lowestPrice",
                            "accumulatedVal",
                            "accumulatedVol",
                            "matchPrice",
                            "matchQtty",
                            "currentPrice",
                            "currentQtty",
                            "projectOpen",
                            "totalRoom",
                            "currentRoom",
                        ),
                        arr[1:],
                    )
                )
            else:
                return dict(
                    zip(
                        (
                            "code",
                            "stockType",
                            "floorCode",
                            "basicPrice",
                            "floorPrice",
                            "ceilingPrice",
                            "bidPrice01",
                            "bidPrice02",
                            "bidPrice03",
                            "bidQtty01",
                            "bidQtty02",
                            "bidQtty03",
                            "offerPrice01",
                            "offerPrice02",
                            "offerPrice03",
                            "offerQtty01",
                            "offerQtty02",
                            "offerQtty03",
                            "totalBidQtty",
                            "totalOfferQtty",
                            "tradingSessionId",
                            "buyForeignQtty",
                            "sellForeignQtty",
                            "highestPrice",
                            "lowestPrice",
                            "accumulatedVal",
                            "accumulatedVol",
                            "matchPrice",
                            "matchQtty",
                            "currentPrice",
                            "currentQtty",
                            "projectOpen",
                            "totalRoom",
                            "currentRoom",
                            "iNav",
                        ),
                        arr[1:],
                    )
                )

        elif arr[0] == "SBA":
            if arr[2] == "ST":
                return dict(
                    zip(
                        (
                            "code",
                            "stockType",
                            "bidPrice01",
                            "bidPrice02",
                            "bidPrice03",
                            "bidPrice04",
                            "bidPrice05",
                            "bidPrice06",
                            "bidPrice07",
                            "bidPrice08",
                            "bidPrice09",
                            "bidPrice10",
                            "bidQtty01",
                            "bidQtty02",
                            "bidQtty03",
                            "bidQtty04",
                            "bidQtty05",
                            "bidQtty06",
                            "bidQtty07",
                            "bidQtty08",
                            "bidQtty09",
                            "bidQtty10",
                            "offerPrice01",
                            "offerPrice02",
                            "offerPrice03",
                            "offerPrice04",
                            "offerPrice05",
                            "offerPrice06",
                            "offerPrice07",
                            "offerPrice08",
                            "offerPrice09",
                            "offerPrice10",
                            "offerQtty01",
                            "offerQtty02",
                            "offerQtty03",
                            "offerQtty04",
                            "offerQtty05",
                            "offerQtty06",
                            "offerQtty07",
                            "offerQtty08",
                            "offerQtty09",
                            "offerQtty10",
                            "totalBidQtty",
                            "totalOfferQtty",
                        ),
                        arr[1:],
                    )
                )
            else:
                return dict(
                    zip(
                        (
                            "code",
                            "stockType",
                            "bidPrice01",
                            "bidPrice02",
                            "bidPrice03",
                            "bidQtty01",
                            "bidQtty02",
                            "bidQtty03",
                            "offerPrice01",
                            "offerPrice02",
                            "offerPrice03",
                            "offerQtty01",
                            "offerQtty02",
                            "offerQtty03",
                            "totalBidQtty",
                            "totalOfferQtty",
                        ),
                        arr[1:],
                    )
                )

        elif arr[0] == "SMA":
            return dict(
                zip(
                    (
                        "code",
                        "stockType",
                        "tradingSessionId",
                        "buyForeignQtty",
                        "sellForeignQtty",
                        "highestPrice",
                        "lowestPrice",
                        "accumulatedVal",
                        "accumulatedVol",
                        "matchPrice",
                        "matchQtty",
                        "currentPrice",
                        "currentQtty",
                        "projectOpen",
                        "totalRoom",
                        "currentRoom",
                        "iNav",
                    ),
                    arr[1:],
                )
            )

        elif arr[0] == "SBS":
            if arr[2] == "W":
                return dict(
                    zip(
                        (
                            "code",
                            "stockType",
                            "floorCode",
                            "basicPrice",
                            "floorPrice",
                            "ceilingPrice",
                            "underlyingSymbol",
                            "issuerName",
                            "exercisePrice",
                            "exerciseRatio",
                        ),
                        arr[1:],
                    )
                )
            else:
                return dict(
                    zip(
                        (
                            "code",
                            "stockType",
                            "floorCode",
                            "basicPrice",
                            "floorPrice",
                            "ceilingPrice",
                        ),
                        arr[1:],
                    )
                )

    elif msg_type == "D":
        if arr[0] == "DFU":
            return dict(
                zip(
                    (
                        "code",
                        "time",
                        "bidPrice01",
                        "bidPrice02",
                        "bidPrice03",
                        "bidPrice04",
                        "bidPrice05",
                        "bidPrice06",
                        "bidPrice07",
                        "bidPrice08",
                        "bidPrice09",
                        "bidPrice10",
                        "bidQtty01",
                        "bidQtty02",
                        "bidQtty03",
                        "bidQtty04",
                        "bidQtty05",
                        "bidQtty06",
                        "bidQtty07",
                        "bidQtty08",
                        "bidQtty09",
                        "bidQtty10",
                        "offerPrice01",
                        "offerPrice02",
                        "offerPrice03",
                        "offerPrice04",
                        "offerPrice05",
                        "offerPrice06",
                        "offerPrice07",
                        "offerPrice08",
                        "offerPrice09",
                        "offerPrice10",
                        "offerQtty01",
                        "offerQtty02",
                        "offerQtty03",
                        "offerQtty04",
                        "offerQtty05",
                        "offerQtty06",
                        "offerQtty07",
                        "offerQtty08",
                        "offerQtty09",
                        "offerQtty10",
                        "totalBidQtty",
                        "totalOfferQtty",
                        "tradingSessionId",
                        "buyForeignQtty",
                        "sellForeignQtty",
                        "highestPrice",
                        "lowestPrice",
                        "accumulatedVal",
                        "accumulatedVol",
                        "matchPrice",
                        "currentPrice",
                        "matchQtty",
                        "currentQtty",
                        "floorCode",
                        "stockType",
                        "tradingDate",
                        "lastTradingDate",
                        "underlying",
                        "basicPrice",
                        "floorPrice",
                        "ceilingPrice",
                        "openInterest",
                        "openPrice",
                    ),
                    arr[1:],
                )
            )

        elif arr[0] == "DBA":
            return dict(
                zip(
                    (
                        "code",
                        "bidPrice01",
                        "bidPrice02",
                        "bidPrice03",
                        "bidPrice04",
                        "bidPrice05",
                        "bidPrice06",
                        "bidPrice07",
                        "bidPrice08",
                        "bidPrice09",
                        "bidPrice10",
                        "bidQtty01",
                        "bidQtty02",
                        "bidQtty03",
                        "bidQtty04",
                        "bidQtty05",
                        "bidQtty06",
                        "bidQtty07",
                        "bidQtty08",
                        "bidQtty09",
                        "bidQtty10",
                        "offerPrice01",
                        "offerPrice02",
                        "offerPrice03",
                        "offerPrice04",
                        "offerPrice05",
                        "offerPrice06",
                        "offerPrice07",
                        "offerPrice08",
                        "offerPrice09",
                        "offerPrice10",
                        "offerQtty01",
                        "offerQtty02",
                        "offerQtty03",
                        "offerQtty04",
                        "offerQtty05",
                        "offerQtty06",
                        "offerQtty07",
                        "offerQtty08",
                        "offerQtty09",
                        "offerQtty10",
                        "totalBidQtty",
                        "totalOfferQtty",
                    ),
                    arr[1:],
                )
            )

        elif arr[0] == "DMA":
            return dict(
                zip(
                    (
                        "code",
                        "time",
                        "tradingSessionId",
                        "buyForeignQtty",
                        "sellForeignQtty",
                        "highestPrice",
                        "lowestPrice",
                        "accumulatedVal",
                        "accumulatedVol",
                        "matchPrice",
                        "currentPrice",
                        "matchQtty",
                        "currentQtty",
                    ),
                    arr[1:],
                ),
            )

        elif arr[0] == "DBS":
            return dict(
                zip(
                    (
                        "code",
                        "floorCode",
                        "stockType",
                        "tradingDate",
                        "lastTradingDate",
                        "underlying",
                        "basicPrice",
                        "floorPrice",
                        "ceilingPrice",
                        "openInterest",
                        "openPrice",
                    ),
                    arr[1:],
                )
            )
        else:
            raise NotImplementedError

    elif msg_type == "MI":
        if arr[0] == "MI":
            return dict(
                zip(
                    (
                        "floorCode",
                        "tradingTime",
                        "status",
                        "advance",
                        "noChange",
                        "decline",
                        "marketIndex",
                        "priorMarketIndex",
                        "highestIndex",
                        "lowestIndex",
                        "totalShareTraded",
                        "totalValueTraded",
                        "totalNormalTradedQttyRd",
                        "totalNormalTradedValueRd",
                        "predictionIndex",
                    ),
                    arr[1:],
                )
            )
        else:
            raise NotImplementedError

# %%
def decode_websocket_message(msg):
    msg_type = msg.split("|")[0]
    msg_data = "|".join(msg.split("|")[1:])

    if msg_type == "d":
        decode_type = msg_data.split(":")[0]
        data = ":".join(msg_data.split(":")[1:])

        arr = "".join(
            list(
                map(
                    lambda x: chr(ord(x[1]) + x[0] % 5),
                    enumerate(data),
                )
            )
        ).split("|")

        return msgArrayToDict(decode_type, arr)
    else:
        raise NotImplementedError


decode_websocket_message(
    "d|S:SL?yCVQzPx|4.6,|0/4,|03+5|03+35{/0*136.3|71//0{/2*8{0-x|{/2*9{3/,0/.-,|37546/6.*4{"
)
# Out:
# {'code': 'GVR',
#  'stockType': 'S',
#  'tradingSessionId': '',
#  'buyForeignQtty': '5090',
#  'sellForeignQtty': '1170',
#  'highestPrice': '15.9',
#  'lowestPrice': '15.75',
#  'accumulatedVal': '13.14817',
#  'accumulatedVol': '83230',
#  'matchPrice': '15.8',
#  'matchQtty': '20',
#  'currentPrice': '',
#  'currentQtty': '',
#  'projectOpen': '15.9',
#  'totalRoom': '52000000',
#  'currentRoom': '49886081.4',
#  'iNav': ''}

# %%
from enum import Enum


class TypeMsg(Enum):
    ACKNOWLEDGE = "a"
    CONNECTION = "c"
    DATA = "d"
    PING = "0"
    PONG = "1"
    REQUEST_SNAPSHOT = "ss"
    RESET = "r"
    SUBSCRIBE = "s"
    UNSUBSCRIBE = "u"
    VERSION = "v"


def sendMessage(typeMsg: TypeMsg, **kwargs):
    if typeMsg in [TypeMsg.ACKNOWLEDGE, TypeMsg.PONG]:
        return typeMsg.value

    if typeMsg in [TypeMsg.SUBSCRIBE, TypeMsg.UNSUBSCRIBE]:
        name = kwargs["name"]
        codes = kwargs["codes"]

        assert name is not None
        assert codes is not None
        return f"{typeMsg.value}|{name}:{','.join(codes)}"

    if typeMsg == TypeMsg.REQUEST_SNAPSHOT:
        type = kwargs["type"]

        if type in ["S", "D"]:
            codes = kwargs["codes"]

            return f"{typeMsg.value}|{type}:code={','.join(codes)}"

        elif type == "MI":
            codes = kwargs["codes"]

            return f"{typeMsg.value}|{type}:floorCode={','.join(codes)}"

        elif type == "CF":
            codes = kwargs["codes"]

            return f"{typeMsg.value}|{type}:floor={','.join(codes)}"

        else:
            raise NotImplementedError

# %%
import asyncio

import websockets

from websockets.sync.client import connect


with connect("wss://price-api-free.vndirect.com.vn/realtime") as websocket:
    websocket.send("a")
    websocket.send("s|MI:10,11,12,13,02,03,VN100,VNDIAMOND")
    websocket.send("s|CF:10,11,12,13,02,03,VN100,VNDIAMOND")
    websocket.send(
        "s|S:ACB,BCM,BID,BVH,CTG,FPT,GAS,GVR,HDB,HPG,MBB,MSN,MWG,NVL,PDR,PLX,POW,SAB,SSI,STB,TCB,TPB,VCB,VHM,VIB,VIC,VJC,VNM,VPB,VRE"
    )
    websocket.send(
        "ss|S:code=ACB,BCM,BID,BVH,CTG,FPT,GAS,GVR,HDB,HPG,MBB,MSN,MWG,NVL,PDR,PLX,POW,SAB,SSI,STB,TCB,TPB,VCB,VHM,VIB,VIC,VJC,VNM,VPB,VRE"
    )

    while True:
        message = websocket.recv()

        print("< {}".format(message))

# %%
from websockets.sync.client import connect

with connect(
    "wss://dchart-socket.vndirect.com.vn/socket.io/?symbol=VN30F1M&EIO=3&transport=websocket&sid=f97251b3-c9e3-427c-b4fb-3c5201a843ad"
) as websocket:
    websocket.send("2probe")
    websocket.send("""42/socket.io,["addsymbol","ACB"]""")
    websocket.send("""42/socket.io,["addsymbol","SSI"]""")
    websocket.send("""42/socket.io,["addsymbol","STB"]""")
    websocket.send("2")
    websocket.send("2")

    while True:
        message = websocket.recv()

        print("< {}".format(message))
